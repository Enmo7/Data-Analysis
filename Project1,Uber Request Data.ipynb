# %% [markdown]
# # Uber Request Data

# %% [markdown]
# ## Data Cleaning:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Uber Request Data.csv")
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
data= df.copy()
data
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
data.head()
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
data.tail()
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 6740  15-07-2016 23:49:03            NaN
# 6741  15-07-2016 23:50:05            NaN
# 6742  15-07-2016 23:52:06            NaN
# 6743  15-07-2016 23:54:39            NaN
# 6744  15-07-2016 23:55:03            NaN

# %%
data.columns
# Out:
# Index(['Request id', 'Pickup point', 'Driver id', 'Status',
#        'Request timestamp', 'Drop timestamp'],
#       dtype='object')

# %%
data.shape
# Out:
# (6745, 6)

# %%
data.info
# Out:
# <bound method DataFrame.info of       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB

# %%
data.dtypes
# Out:
# Request id             int64
# Pickup point          object
# Driver id            float64
# Status                object
# Request timestamp     object
# Drop timestamp        object
# dtype: object

# %%
data.isna().sum()
# Out:
# Request id              0
# Pickup point            0
# Driver id            2650
# Status                  0
# Request timestamp       0
# Drop timestamp       3914
# dtype: int64

# %%
data.nunique()
# Out:
# Request id           6745
# Pickup point            2
# Driver id             300
# Status                  3
# Request timestamp    5618
# Drop timestamp       2598
# dtype: int64

# %%
data['Driver id'].unique
# Out:
# <bound method Series.unique of 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 6740    NaN
# 6741    NaN
# 6742    NaN
# 6743    NaN
# 6744    NaN
# Name: Driver id, Length: 6745, dtype: float64>

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Driver id'].unique
# Out:
# <bound method Series.unique of 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 6740    NaN
# 6741    NaN
# 6742    NaN
# 6743    NaN
# 6744    NaN
# Name: Driver id, Length: 6745, dtype: float64>

# %%
data['Driver id'].notna().astype('str')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6740    False
# 6741    False
# 6742    False
# 6743    False
# 6744    False
# Name: Driver id, Length: 6745, dtype: object

# %%
data['Driver id'].isnull().values.any()
# Out:
# True

# %%
data['Driver id'].isnull().sum()
# Out:
# 2650

# %%
data.dtypes
# Out:
# Request id             int64
# Pickup point          object
# Driver id            float64
# Status                object
# Request timestamp     object
# Drop timestamp        object
# dtype: object

# %% [markdown]
# ## Data Analysis:

# %% [markdown]
# ### Analysis of Status:

# %%
data['Status']
# Out:
# 0          Trip Completed
# 1          Trip Completed
# 2          Trip Completed
# 3          Trip Completed
# 4          Trip Completed
#               ...
# 6740    No Cars Available
# 6741    No Cars Available
# 6742    No Cars Available
# 6743    No Cars Available
# 6744    No Cars Available
# Name: Status, Length: 6745, dtype: object

# %% [markdown]
# #### How many people Cancelled?

# %%
data['Status'].str.contains('Cancelled',case=False, regex=False).sum()
# Out:
# 1264

# %% [markdown]
# #### How many people Completed ?

# %%
data['Status'].str.contains('Trip Completed',case=False, regex=False).sum()
# Out:
# 2831

# %% [markdown]
# #### How many Cars is not Available ?

# %%
data['Status'].str.contains('No Cars Available',case=False, regex=False).sum()
# Out:
# 2650

# %% [markdown]
# #### Compare between ( Trip Completed, Cancelled, No Cars Available):

# %%
data['Status'].value_counts().nlargest().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analysis on Pickup point:

# %% [markdown]
# #### How many request in city ?

# %% [markdown]
# In General ( Completed, Cancelled, No Car Available)

# %%
data['Pickup point'].str.contains('City',case=False, regex=False).sum()
# Out:
# 3507

# %% [markdown]
# #### How many request in Airport ?

# %% [markdown]
# In General ( Completed, Cancelled, No Car Available)

# %%
data['Pickup point'].str.contains('Airport',case=False, regex=False).sum()
# Out:
# 3238

# %% [markdown]
# #### Compare between city and airport:

# %% [markdown]
# In General ( Completed, Cancelled, No Car Available)

# %%
data['Pickup point'].value_counts().nlargest().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Relationship between Status and Pickup point :

# %% [markdown]
# #### How many the Cancelled request in city ?

# %% [markdown]
# Number of Cancelled request in City.

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'Cancelled')]
# Out:
#       Request id Pickup point  Driver id     Status    Request timestamp  \
# 2831        2905         City        1.0  Cancelled  13-07-2016 06:08:41
# 2832        4805         City        1.0  Cancelled  14-07-2016 17:07:58
# 2834        5927         City        1.0  Cancelled  15-07-2016 10:12:40
# 2837        4451         City        2.0  Cancelled  14-07-2016 08:38:38
# 2839          80         City        3.0  Cancelled       11/7/2016 4:47
# ...          ...          ...        ...        ...                  ...
# 4090        1641         City      299.0  Cancelled       12/7/2016 7:20
# 4091        4158         City      299.0  Cancelled  14-07-2016 05:03:10
# 4092        4164         City      299.0  Cancelled  14-07-2016 05:06:40
# 4093        4448         City      299.0  Cancelled  14-07-2016 08:30:59
# 4094        4225         City      300.0  Cancelled  14-07-2016 05:46:06
#
#      Drop timestamp
# 2831            NaN
# 2832            NaN
# 2834            NaN
# ...

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'Cancelled')].shape
# Out:
# (1066, 6)

# %% [markdown]
# #### How many completed request in city ?

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'Trip Completed')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 2           1807         City        1.0  Trip Completed       12/7/2016 9:17
# 4           3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 8           6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9            267         City        2.0  Trip Completed       11/7/2016 6:46
# 11          1983         City        2.0  Trip Completed      12/7/2016 12:30
# ...          ...          ...        ...             ...                  ...
# 2820        2249         City      299.0  Trip Completed      12/7/2016 18:24
# 2823        4481         City      299.0  Trip Completed  14-07-2016 08:46:30
# 2824        5160         City      299.0  Trip Completed  14-07-2016 20:28:32
# 2825        6304         City      299.0  Trip Completed  15-07-2016 18:31:31
# 2827        2924         City      300.0  Trip Completed  13-07-2016 06:31:22
#
#            Drop timestamp
# ...

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'Trip Completed')].shape
# Out:
# (1504, 6)

# %% [markdown]
# #### How many the not Available cars in city ?

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'No Cars Available')]
# Out:
#       Request id Pickup point  Driver id             Status  \
# 4095        1362         City        NaN  No Cars Available
# 4096        1364         City        NaN  No Cars Available
# 4097        1366         City        NaN  No Cars Available
# 4100           6         City        NaN  No Cars Available
# 4101           4         City        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 4095       11/7/2016 0:02            NaN
# 4096       11/7/2016 0:06            NaN
# 4097       11/7/2016 0:09            NaN
# 4100       11/7/2016 0:36            NaN
# ...

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'No Cars Available')].shape
# Out:
# (937, 6)

# %% [markdown]
# #### How many the Cancelled request in Airport?

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'Cancelled')]
# Out:
#       Request id Pickup point  Driver id     Status    Request timestamp  \
# 2833        5202      Airport        1.0  Cancelled  14-07-2016 20:51:37
# 2835        2347      Airport        2.0  Cancelled      12/7/2016 19:14
# 2836        3806      Airport        2.0  Cancelled  13-07-2016 20:57:49
# 2838        5023      Airport        2.0  Cancelled  14-07-2016 19:04:08
# 2841        1867      Airport        3.0  Cancelled       12/7/2016 9:59
# ...          ...          ...        ...        ...                  ...
# 4043        3451      Airport      287.0  Cancelled  13-07-2016 16:53:56
# 4044        3839      Airport      287.0  Cancelled  13-07-2016 21:28:41
# 4046        4677      Airport      287.0  Cancelled  14-07-2016 12:45:00
# 4049        2094      Airport      288.0  Cancelled      12/7/2016 15:51
# 4081         295      Airport      297.0  Cancelled       11/7/2016 7:10
#
#      Drop timestamp
# 2833            NaN
# 2835            NaN
# 2836            NaN
# ...

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'Cancelled')].shape
# Out:
# (198, 6)

# %% [markdown]
# #### How many completed request in Airport?

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'Trip Completed')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 0            619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1            867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 3           2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 5           3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6           4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# ...          ...          ...        ...             ...                  ...
# 2822        3817      Airport      299.0  Trip Completed  13-07-2016 21:12:43
# 2826        1315      Airport      300.0  Trip Completed      11/7/2016 22:54
# 2828        3324      Airport      300.0  Trip Completed  13-07-2016 12:33:21
# 2829        3935      Airport      300.0  Trip Completed  13-07-2016 22:26:08
# 2830        5844      Airport      300.0  Trip Completed  15-07-2016 09:07:09
#
#            Drop timestamp
# ...

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'Trip Completed')].shape
# Out:
# (1327, 6)

# %% [markdown]
# #### How many the not Available cars in Airport?

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'No Cars Available')]
# Out:
#       Request id Pickup point  Driver id             Status  \
# 4098           2      Airport        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# 4104          16      Airport        NaN  No Cars Available
# 4105          14      Airport        NaN  No Cars Available
# 4108          17      Airport        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 4098       11/7/2016 0:23            NaN
# 4099       11/7/2016 0:30            NaN
# 4104       11/7/2016 1:09            NaN
# 4105       11/7/2016 1:10            NaN
# ...

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'No Cars Available')].shape
# Out:
# (1713, 6)

# %% [markdown]
# #### Compare bitween ( Trip Completed, Cancelled, No Cars Available) in city and airport:

# %%
plt.figure(figsize=(15,8))
sns.countplot(data= data, x='Pickup point', hue='Status')
# Out:
# <AxesSubplot:xlabel='Pickup point', ylabel='count'>

# %% [markdown]
# ### How many people did not find a car to transport them?

# %% [markdown]
# #### In City:

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'No Cars Available')]
# Out:
#       Request id Pickup point  Driver id             Status  \
# 4095        1362         City        NaN  No Cars Available
# 4096        1364         City        NaN  No Cars Available
# 4097        1366         City        NaN  No Cars Available
# 4100           6         City        NaN  No Cars Available
# 4101           4         City        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 4095       11/7/2016 0:02            NaN
# 4096       11/7/2016 0:06            NaN
# 4097       11/7/2016 0:09            NaN
# 4100       11/7/2016 0:36            NaN
# ...

# %%
data[(data['Pickup point']== 'City') & (data['Status']== 'No Cars Available')].shape
# Out:
# (937, 6)

# %% [markdown]
# #### In Airport:

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'No Cars Available')]
# Out:
#       Request id Pickup point  Driver id             Status  \
# 4098           2      Airport        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# 4104          16      Airport        NaN  No Cars Available
# 4105          14      Airport        NaN  No Cars Available
# 4108          17      Airport        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp Drop timestamp
# 4098       11/7/2016 0:23            NaN
# 4099       11/7/2016 0:30            NaN
# 4104       11/7/2016 1:09            NaN
# 4105       11/7/2016 1:10            NaN
# ...

# %%
data[(data['Pickup point']== 'Airport') & (data['Status']== 'No Cars Available')].shape
# Out:
# (1713, 6)

# %% [markdown]
# ### Who is the most requested driver in General?

# %% [markdown]
# This is The most requested driver in general ( Completed, Cancelled).

# %% [markdown]
# #### What is the number of  the most request driver ?

# %%
data['Driver id'].value_counts().idxmax()
# data['Driver id'].mode()
# We Can Get the Sam solution by this codes
# data['Driver id'].mode().value_counts()
# Out:
# 27.0

# %% [markdown]
# #### Who are they and how many are they?

# %% [markdown]
# Pickup point & Status.

# %%
data[data['Driver id']== 27]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 264          204         City       27.0  Trip Completed       11/7/2016 6:04
# 265          632      Airport       27.0  Trip Completed      11/7/2016 12:20
# 266          763         City       27.0  Trip Completed      11/7/2016 16:19
# 267         1786      Airport       27.0  Trip Completed       12/7/2016 9:03
# 268         1968         City       27.0  Trip Completed      12/7/2016 12:10
# 269         2088      Airport       27.0  Trip Completed      12/7/2016 15:51
# 270         2473      Airport       27.0  Trip Completed      12/7/2016 20:43
# 271         2869      Airport       27.0  Trip Completed  13-07-2016 05:50:09
# 272         3742      Airport       27.0  Trip Completed  13-07-2016 20:24:23
# 273         4440      Airport       27.0  Trip Completed  14-07-2016 08:26:29
# 274         5234         City       27.0  Trip Completed  14-07-2016 21:09:47
# ...

# %%
data[data['Driver id']== 27].shape
# Out:
# (22, 6)

# %% [markdown]
# #### What is the number of Trip Completed and Cancelled ?

# %% [markdown]
# ##### Trip Completed:

# %%
data[(data['Driver id']== 27) & (data['Status']== 'Trip Completed')]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 264         204         City       27.0  Trip Completed       11/7/2016 6:04
# 265         632      Airport       27.0  Trip Completed      11/7/2016 12:20
# 266         763         City       27.0  Trip Completed      11/7/2016 16:19
# 267        1786      Airport       27.0  Trip Completed       12/7/2016 9:03
# 268        1968         City       27.0  Trip Completed      12/7/2016 12:10
# 269        2088      Airport       27.0  Trip Completed      12/7/2016 15:51
# 270        2473      Airport       27.0  Trip Completed      12/7/2016 20:43
# 271        2869      Airport       27.0  Trip Completed  13-07-2016 05:50:09
# 272        3742      Airport       27.0  Trip Completed  13-07-2016 20:24:23
# 273        4440      Airport       27.0  Trip Completed  14-07-2016 08:26:29
# 274        5234         City       27.0  Trip Completed  14-07-2016 21:09:47
# ...

# %%
data[(data['Driver id']== 27) & (data['Status']== 'Trip Completed')].shape
# Out:
# (13, 6)

# %% [markdown]
# ##### Cancelled:

# %%
data[(data['Driver id']== 27) & (data['Status']== 'Cancelled')]
# Out:
#       Request id Pickup point  Driver id     Status    Request timestamp  \
# 2919         276         City       27.0  Cancelled       11/7/2016 6:52
# 2920        1613         City       27.0  Cancelled       12/7/2016 6:47
# 2921        3150         City       27.0  Cancelled  13-07-2016 08:59:46
# 2922        3217         City       27.0  Cancelled  13-07-2016 09:48:01
# 2923        4523         City       27.0  Cancelled  14-07-2016 09:22:12
# 2924        4593         City       27.0  Cancelled  14-07-2016 10:09:46
# 2925        5476      Airport       27.0  Cancelled  15-07-2016 04:45:54
# 2926        5477         City       27.0  Cancelled  15-07-2016 04:48:51
# 2927        5846         City       27.0  Cancelled  15-07-2016 09:05:17
#
#      Drop timestamp
# 2919            NaN
# 2920            NaN
# 2921            NaN
# 2922            NaN
# 2923            NaN
# 2924            NaN
# 2925            NaN
# 2926            NaN
# 2927            NaN

# %%
data[(data['Driver id']== 27) & (data['Status']== 'Cancelled')].shape
# Out:
# (9, 6)

# %% [markdown]
# #### What is the number for both Trip Completed and Cancelled in city and Airport?

# %% [markdown]
# ##### In City:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 264          204         City       27.0  Trip Completed       11/7/2016 6:04
# 266          763         City       27.0  Trip Completed      11/7/2016 16:19
# 268         1968         City       27.0  Trip Completed      12/7/2016 12:10
# 274         5234         City       27.0  Trip Completed  14-07-2016 21:09:47
# 276         6638         City       27.0  Trip Completed  15-07-2016 21:59:10
# 2919         276         City       27.0       Cancelled       11/7/2016 6:52
# 2920        1613         City       27.0       Cancelled       12/7/2016 6:47
# 2921        3150         City       27.0       Cancelled  13-07-2016 08:59:46
# 2922        3217         City       27.0       Cancelled  13-07-2016 09:48:01
# 2923        4523         City       27.0       Cancelled  14-07-2016 09:22:12
# 2924        4593         City       27.0       Cancelled  14-07-2016 10:09:46
# ...

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City')].shape
# Out:
# (13, 6)

# %% [markdown]
# ##### In Airport:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 265          632      Airport       27.0  Trip Completed      11/7/2016 12:20
# 267         1786      Airport       27.0  Trip Completed       12/7/2016 9:03
# 269         2088      Airport       27.0  Trip Completed      12/7/2016 15:51
# 270         2473      Airport       27.0  Trip Completed      12/7/2016 20:43
# 271         2869      Airport       27.0  Trip Completed  13-07-2016 05:50:09
# 272         3742      Airport       27.0  Trip Completed  13-07-2016 20:24:23
# 273         4440      Airport       27.0  Trip Completed  14-07-2016 08:26:29
# 275         6354      Airport       27.0  Trip Completed  15-07-2016 18:59:01
# 2925        5476      Airport       27.0       Cancelled  15-07-2016 04:45:54
#
#            Drop timestamp
# 265       11/7/2016 13:10
# 267        12/7/2016 9:58
# 269       12/7/2016 17:02
# 270       12/7/2016 21:20
# 271   13-07-2016 06:27:07
# ...

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport')].shape
# Out:
# (9, 6)

# %% [markdown]
# #### What is the number of request Cancelled in City & Airport?

# %% [markdown]
# ##### In City:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City') & (data['Status']== 'Cancelled')]
# Out:
#       Request id Pickup point  Driver id     Status    Request timestamp  \
# 2919         276         City       27.0  Cancelled       11/7/2016 6:52
# 2920        1613         City       27.0  Cancelled       12/7/2016 6:47
# 2921        3150         City       27.0  Cancelled  13-07-2016 08:59:46
# 2922        3217         City       27.0  Cancelled  13-07-2016 09:48:01
# 2923        4523         City       27.0  Cancelled  14-07-2016 09:22:12
# 2924        4593         City       27.0  Cancelled  14-07-2016 10:09:46
# 2926        5477         City       27.0  Cancelled  15-07-2016 04:48:51
# 2927        5846         City       27.0  Cancelled  15-07-2016 09:05:17
#
#      Drop timestamp
# 2919            NaN
# 2920            NaN
# 2921            NaN
# 2922            NaN
# 2923            NaN
# 2924            NaN
# 2926            NaN
# 2927            NaN

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City') & (data['Status']== 'Cancelled')].shape
# Out:
# (8, 6)

# %% [markdown]
# ##### In Airport:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport') & (data['Status']== 'Cancelled')]
# Out:
#       Request id Pickup point  Driver id     Status    Request timestamp  \
# 2925        5476      Airport       27.0  Cancelled  15-07-2016 04:45:54
#
#      Drop timestamp
# 2925            NaN

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport') & (data['Status']== 'Cancelled')].shape
# Out:
# (1, 6)

# %% [markdown]
# #### What is the number of request Trip Completed in City & Airport?

# %% [markdown]
# ##### In City:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City') & (data['Status']== 'Trip Completed')]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 264         204         City       27.0  Trip Completed       11/7/2016 6:04
# 266         763         City       27.0  Trip Completed      11/7/2016 16:19
# 268        1968         City       27.0  Trip Completed      12/7/2016 12:10
# 274        5234         City       27.0  Trip Completed  14-07-2016 21:09:47
# 276        6638         City       27.0  Trip Completed  15-07-2016 21:59:10
#
#           Drop timestamp
# 264       11/7/2016 6:44
# 266      11/7/2016 17:25
# 268      12/7/2016 12:49
# 274  14-07-2016 21:52:37
# 276  15-07-2016 23:13:18

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'City') & (data['Status']== 'Trip Completed')].shape
# Out:
# (5, 6)

# %% [markdown]
# ##### In Airport:

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport') & (data['Status']== 'Trip Completed')]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 265         632      Airport       27.0  Trip Completed      11/7/2016 12:20
# 267        1786      Airport       27.0  Trip Completed       12/7/2016 9:03
# 269        2088      Airport       27.0  Trip Completed      12/7/2016 15:51
# 270        2473      Airport       27.0  Trip Completed      12/7/2016 20:43
# 271        2869      Airport       27.0  Trip Completed  13-07-2016 05:50:09
# 272        3742      Airport       27.0  Trip Completed  13-07-2016 20:24:23
# 273        4440      Airport       27.0  Trip Completed  14-07-2016 08:26:29
# 275        6354      Airport       27.0  Trip Completed  15-07-2016 18:59:01
#
#           Drop timestamp
# 265      11/7/2016 13:10
# 267       12/7/2016 9:58
# 269      12/7/2016 17:02
# 270      12/7/2016 21:20
# 271  13-07-2016 06:27:07
# 272  13-07-2016 20:48:05
# 273  14-07-2016 09:00:36
# 275  15-07-2016 19:35:10

# %%
data[(data['Driver id']== 27) & (data['Pickup point']== 'Airport') & (data['Status']== 'Trip Completed')].shape
# Out:
# (8, 6)

# %% [markdown]
# ### How many Drivers Can Completed there jop?

# %% [markdown]
# These are the drivers who have finished their work.

# %% [markdown]
# #### Create new data frame:

# %% [markdown]
# We will create a new data frame to preserve the original data if we need it.

# %%
data1= data.copy()
data1
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %% [markdown]
# #### Drop NAN Values:

# %% [markdown]
# We will Drop all NAN values in rows and this includes (Cancelled & No Car Available).

# %%
# data.dropna().reset_index(drop=True ,inplace=True)
data1.dropna()
data1.dropna(axis=0 ,inplace=True)
data1
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 0            619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1            867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2           1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3           2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4           3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# ...          ...          ...        ...             ...                  ...
# 2826        1315      Airport      300.0  Trip Completed      11/7/2016 22:54
# 2827        2924         City      300.0  Trip Completed  13-07-2016 06:31:22
# 2828        3324      Airport      300.0  Trip Completed  13-07-2016 12:33:21
# 2829        3935      Airport      300.0  Trip Completed  13-07-2016 22:26:08
# 2830        5844      Airport      300.0  Trip Completed  15-07-2016 09:07:09
#
#            Drop timestamp
# ...

# %%
data1.shape
# Out:
# (2831, 6)

# %% [markdown]
# #### In City:

# %%
data1[(data1['Pickup point']== 'City') & (data1['Status']== 'Trip Completed')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 2           1807         City        1.0  Trip Completed       12/7/2016 9:17
# 4           3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 8           6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9            267         City        2.0  Trip Completed       11/7/2016 6:46
# 11          1983         City        2.0  Trip Completed      12/7/2016 12:30
# ...          ...          ...        ...             ...                  ...
# 2820        2249         City      299.0  Trip Completed      12/7/2016 18:24
# 2823        4481         City      299.0  Trip Completed  14-07-2016 08:46:30
# 2824        5160         City      299.0  Trip Completed  14-07-2016 20:28:32
# 2825        6304         City      299.0  Trip Completed  15-07-2016 18:31:31
# 2827        2924         City      300.0  Trip Completed  13-07-2016 06:31:22
#
#            Drop timestamp
# ...

# %%
data1[(data1['Pickup point']== 'City') & (data1['Status']== 'Trip Completed')].shape
# Out:
# (1504, 6)

# %% [markdown]
# #### In Airport:

# %%
data1[(data1['Pickup point']== 'Airport') & (data1['Status']== 'Trip Completed')]
# Out:
#       Request id Pickup point  Driver id          Status    Request timestamp  \
# 0            619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1            867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 3           2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 5           3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6           4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# ...          ...          ...        ...             ...                  ...
# 2822        3817      Airport      299.0  Trip Completed  13-07-2016 21:12:43
# 2826        1315      Airport      300.0  Trip Completed      11/7/2016 22:54
# 2828        3324      Airport      300.0  Trip Completed  13-07-2016 12:33:21
# 2829        3935      Airport      300.0  Trip Completed  13-07-2016 22:26:08
# 2830        5844      Airport      300.0  Trip Completed  15-07-2016 09:07:09
#
#            Drop timestamp
# ...

# %%
data1[(data1['Pickup point']== 'Airport') & (data1['Status']== 'Trip Completed')].shape
# Out:
# (1327, 6)

# %% [markdown]
# #### The Relationship between City & Airport:

# %%
plt.figure(figsize=(9,8))
sns.countplot(data= data1, x='Pickup point', hue='Status')
# Out:
# <AxesSubplot:xlabel='Pickup point', ylabel='count'>

# %%
sns.jointplot(x='Pickup point',y='Status',data=data1)

# %% [markdown]
# ### Who is the most successful driver?

# %% [markdown]
# #### The Driver is:

# %%
data1['Driver id'].value_counts(). idxmax()
# data1['Driver id'].mode()
# Out:
# 22.0

# %%
data1[data1['Driver id']== 22]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 199         110         City       22.0  Trip Completed       11/7/2016 5:05
# 200         362         City       22.0  Trip Completed       11/7/2016 8:01
# 201         666      Airport       22.0  Trip Completed      11/7/2016 13:02
# 202         926         City       22.0  Trip Completed      11/7/2016 18:28
# 203        1180      Airport       22.0  Trip Completed      11/7/2016 21:01
# 204        1900         City       22.0  Trip Completed      12/7/2016 10:32
# 205        2506         City       22.0  Trip Completed      12/7/2016 21:01
# 206        3064         City       22.0  Trip Completed  13-07-2016 08:02:03
# 207        3327      Airport       22.0  Trip Completed  13-07-2016 12:24:41
# 208        3601         City       22.0  Trip Completed  13-07-2016 18:39:00
# 209        4768      Airport       22.0  Trip Completed  14-07-2016 15:39:24
# ...

# %% [markdown]
# #### How many This Driver do his jop in general?

# %%
data1[data1['Driver id']== 22].shape
# Out:
# (16, 6)

# %% [markdown]
# #### How many this Driver do his jop in city?

# %%
data1[(data1['Driver id']== 22) & (data1['Pickup point']== 'City')]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 199         110         City       22.0  Trip Completed       11/7/2016 5:05
# 200         362         City       22.0  Trip Completed       11/7/2016 8:01
# 202         926         City       22.0  Trip Completed      11/7/2016 18:28
# 204        1900         City       22.0  Trip Completed      12/7/2016 10:32
# 205        2506         City       22.0  Trip Completed      12/7/2016 21:01
# 206        3064         City       22.0  Trip Completed  13-07-2016 08:02:03
# 208        3601         City       22.0  Trip Completed  13-07-2016 18:39:00
# 210        5142         City       22.0  Trip Completed  14-07-2016 20:17:51
# 212        5575         City       22.0  Trip Completed  15-07-2016 05:53:55
# 213        5902         City       22.0  Trip Completed  15-07-2016 09:52:57
#
#           Drop timestamp
# 199       11/7/2016 6:06
# 200       11/7/2016 9:18
# 202      11/7/2016 19:34
# ...

# %%
data1[(data1['Driver id']== 22) & (data1['Pickup point']== 'City')].shape
# Out:
# (10, 6)

# %% [markdown]
# #### How many this Driver do his jop in Airport?

# %%
data1[(data1['Driver id']== 22) & (data1['Pickup point']== 'Airport')]
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 201         666      Airport       22.0  Trip Completed      11/7/2016 13:02
# 203        1180      Airport       22.0  Trip Completed      11/7/2016 21:01
# 207        3327      Airport       22.0  Trip Completed  13-07-2016 12:24:41
# 209        4768      Airport       22.0  Trip Completed  14-07-2016 15:39:24
# 211        5366      Airport       22.0  Trip Completed  14-07-2016 23:27:22
# 214        6694      Airport       22.0  Trip Completed  15-07-2016 22:45:44
#
#           Drop timestamp
# 201      11/7/2016 13:45
# 203      11/7/2016 22:14
# 207  13-07-2016 13:23:39
# 209  14-07-2016 16:49:03
# 211  15-07-2016 00:19:50
# 214  15-07-2016 23:17:53

# %%
data1[(data1['Driver id']== 22) & (data1['Pickup point']== 'Airport')].shape
# Out:
# (6, 6)

# %% [markdown]
# ### What is the busiest day for orders in General?

# %% [markdown]
# #### Change data type for (Drop timestamp, Request timestamp)

# %%
# The Original data
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
# Change data type for (Drop timestamp, Request timestamp)
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'])
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'])

# %% [markdown]
# #### Separating date from time:

# %% [markdown]
# The date will be separated from the time, each in a special column, in order to find the busiest day.

# %%
df['new_date_Request_timestamp'] = [d.date() for d in df['Request timestamp']]
df['new_time_Request_timestamp'] = [d.time() for d in df['Request timestamp']]
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp new_date_Request_timestamp  \
# 0    2016-11-07 11:51:00 2016-11-07 13:00:00                 2016-11-07
# 1    2016-11-07 17:57:00 2016-11-07 18:47:00                 2016-11-07
# ...

# %% [markdown]
# #### Change data type for ( new_date_Request_timestamp) column:

# %%
df['new_date_Request_timestamp'] = pd.to_datetime(df['new_date_Request_timestamp'])

# %%
df.dtypes
# Out:
# Request id                             int64
# Pickup point                          object
# Driver id                            float64
# Status                                object
# Request timestamp             datetime64[ns]
# Drop timestamp                datetime64[ns]
# new_date_Request_timestamp    datetime64[ns]
# new_time_Request_timestamp            object
# dtype: object

# %% [markdown]
# #### The most requested day:

# %% [markdown]
# In General.

# %%
df['new_date_Request_timestamp']
# Out:
# 0      2016-11-07
# 1      2016-11-07
# 2      2016-12-07
# 3      2016-12-07
# 4      2016-07-13
#           ...
# 6740   2016-07-15
# 6741   2016-07-15
# 6742   2016-07-15
# 6743   2016-07-15
# 6744   2016-07-15
# Name: new_date_Request_timestamp, Length: 6745, dtype: datetime64[ns]

# %%
# df['Request timestamp'].dt.date.mode()
df['new_date_Request_timestamp'].value_counts().idxmax()
# Out:
# Timestamp('2016-07-15 00:00:00')

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 7           5510      Airport        1.0     Trip Completed
# 8           6248         City        1.0     Trip Completed
# 26          5434         City        3.0     Trip Completed
# 27          5916         City        3.0     Trip Completed
# 36          5771      Airport        4.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp new_date_Request_timestamp  \
# 7    2016-07-15 05:11:52 2016-07-15 06:07:52                 2016-07-15
# 8    2016-07-15 17:57:27 2016-07-15 18:50:51                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (1381, 8)

# %% [markdown]
# ##### How many trips have been completed in this day?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Status'] == 'Trip Completed')]
filtered_df
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 7           5510      Airport        1.0  Trip Completed 2016-07-15 05:11:52
# 8           6248         City        1.0  Trip Completed 2016-07-15 17:57:27
# 26          5434         City        3.0  Trip Completed 2016-07-15 02:41:38
# 27          5916         City        3.0  Trip Completed 2016-07-15 10:00:43
# 36          5771      Airport        4.0  Trip Completed 2016-07-15 08:30:06
# ...          ...          ...        ...             ...                 ...
# 2796        5634      Airport      296.0  Trip Completed 2016-07-15 06:44:16
# 2807        6067      Airport      297.0  Trip Completed 2016-07-15 13:55:13
# 2818        6271         City      298.0  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City      299.0  Trip Completed 2016-07-15 18:31:31
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %%
filtered_df.shape
# Out:
# (561, 8)

# %% [markdown]
# ##### How many trips have been cancelled in this day?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Status'] == 'Cancelled')]
filtered_df
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 2834        5927         City        1.0  Cancelled 2016-07-15 10:12:40
# 2851        5547         City        6.0  Cancelled 2016-07-15 05:30:31
# 2852        5699         City        6.0  Cancelled 2016-07-15 07:25:53
# 2853        5701         City        6.0  Cancelled 2016-07-15 07:34:00
# 2883        5784         City       16.0  Cancelled 2016-07-15 08:34:59
# ...          ...          ...        ...        ...                 ...
# 4067        5812         City      293.0  Cancelled 2016-07-15 08:44:40
# 4079        5514         City      296.0  Cancelled 2016-07-15 05:08:25
# 4080        5690         City      296.0  Cancelled 2016-07-15 07:20:54
# 4083        5515         City      297.0  Cancelled 2016-07-15 05:13:03
# 4084        5535         City      297.0  Cancelled 2016-07-15 05:19:48
#
#      Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# ...

# %%
filtered_df.shape
# Out:
# (240, 8)

# %% [markdown]
# ##### How many trips People cannot fined cars?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Status'] == 'No Cars Available')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6165        6765      Airport        NaN  No Cars Available
# 6166        5388      Airport        NaN  No Cars Available
# 6167        5387         City        NaN  No Cars Available
# 6168        5389      Airport        NaN  No Cars Available
# 6169        5386         City        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp Drop timestamp new_date_Request_timestamp  \
# 6165 2016-07-15 00:09:09            NaT                 2016-07-15
# 6166 2016-07-15 00:19:05            NaT                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (580, 8)

# %% [markdown]
# ##### How many trips in City & Airport?

# %% [markdown]
# ###### In City:

# %% [markdown]
# In General.

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 8           6248         City        1.0     Trip Completed
# 26          5434         City        3.0     Trip Completed
# 27          5916         City        3.0     Trip Completed
# 57          5741         City        6.0     Trip Completed
# 65          5898         City        7.0     Trip Completed
# ...          ...          ...        ...                ...
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp new_date_Request_timestamp  \
# 8    2016-07-15 17:57:27 2016-07-15 18:50:51                 2016-07-15
# 26   2016-07-15 02:41:38 2016-07-15 03:24:43                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (752, 8)

# %% [markdown]
# ###### In Airport:

# %% [markdown]
# In General.

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 7           5510      Airport        1.0     Trip Completed
# 36          5771      Airport        4.0     Trip Completed
# 37          6106      Airport        4.0     Trip Completed
# 47          5857      Airport        5.0     Trip Completed
# 48          6690      Airport        5.0     Trip Completed
# ...          ...          ...        ...                ...
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp new_date_Request_timestamp  \
# 7    2016-07-15 05:11:52 2016-07-15 06:07:52                 2016-07-15
# 36   2016-07-15 08:30:06 2016-07-15 09:37:20                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (629, 8)

# %% [markdown]
# ######  How many trips in City & Trip Completed?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City') & (df['Status']== 'Trip Completed')]
filtered_df
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 8           6248         City        1.0  Trip Completed 2016-07-15 17:57:27
# 26          5434         City        3.0  Trip Completed 2016-07-15 02:41:38
# 27          5916         City        3.0  Trip Completed 2016-07-15 10:00:43
# 57          5741         City        6.0  Trip Completed 2016-07-15 07:52:51
# 65          5898         City        7.0  Trip Completed 2016-07-15 09:50:28
# ...          ...          ...        ...             ...                 ...
# 2768        5687         City      293.0  Trip Completed 2016-07-15 07:15:09
# 2780        6509         City      294.0  Trip Completed 2016-07-15 20:32:52
# 2786        6475         City      295.0  Trip Completed 2016-07-15 20:20:10
# 2818        6271         City      298.0  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City      299.0  Trip Completed 2016-07-15 18:31:31
#
# ...

# %%
filtered_df.shape
# Out:
# (293, 8)

# %% [markdown]
# ###### How many trips in City & Cancelled?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City') & (df['Status']== 'Cancelled')]
filtered_df
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 2834        5927         City        1.0  Cancelled 2016-07-15 10:12:40
# 2851        5547         City        6.0  Cancelled 2016-07-15 05:30:31
# 2852        5699         City        6.0  Cancelled 2016-07-15 07:25:53
# 2853        5701         City        6.0  Cancelled 2016-07-15 07:34:00
# 2883        5784         City       16.0  Cancelled 2016-07-15 08:34:59
# ...          ...          ...        ...        ...                 ...
# 4067        5812         City      293.0  Cancelled 2016-07-15 08:44:40
# 4079        5514         City      296.0  Cancelled 2016-07-15 05:08:25
# 4080        5690         City      296.0  Cancelled 2016-07-15 07:20:54
# 4083        5515         City      297.0  Cancelled 2016-07-15 05:13:03
# 4084        5535         City      297.0  Cancelled 2016-07-15 05:19:48
#
#      Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# ...

# %%
filtered_df.shape
# Out:
# (209, 8)

# %% [markdown]
# ###### How many trips in City & People cannot fined cars?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City') & (df['Status']== 'No Cars Available')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6167        5387         City        NaN  No Cars Available
# 6169        5386         City        NaN  No Cars Available
# 6171        5391         City        NaN  No Cars Available
# 6173        5397         City        NaN  No Cars Available
# 6175        5398         City        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6738        6746         City        NaN  No Cars Available
# 6739        6739         City        NaN  No Cars Available
# 6740        6745         City        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
#
#        Request timestamp Drop timestamp new_date_Request_timestamp  \
# 6167 2016-07-15 00:19:53            NaT                 2016-07-15
# 6169 2016-07-15 00:20:52            NaT                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (250, 8)

# %% [markdown]
# ###### How many trips in Airport & Trip Completed?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport') & (df['Status']== 'Trip Completed')]
filtered_df
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 7           5510      Airport        1.0  Trip Completed 2016-07-15 05:11:52
# 36          5771      Airport        4.0  Trip Completed 2016-07-15 08:30:06
# 37          6106      Airport        4.0  Trip Completed 2016-07-15 15:01:20
# 47          5857      Airport        5.0  Trip Completed 2016-07-15 09:08:50
# 48          6690      Airport        5.0  Trip Completed 2016-07-15 22:41:41
# ...          ...          ...        ...             ...                 ...
# 2769        6724      Airport      293.0  Trip Completed 2016-07-15 23:20:36
# 2779        5519      Airport      294.0  Trip Completed 2016-07-15 05:11:57
# 2796        5634      Airport      296.0  Trip Completed 2016-07-15 06:44:16
# 2807        6067      Airport      297.0  Trip Completed 2016-07-15 13:55:13
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %%
filtered_df.shape
# Out:
# (268, 8)

# %% [markdown]
# ###### How many trips in Airport & Cancelled?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport') & (df['Status']== 'Cancelled')]
filtered_df
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 2915        6249      Airport       24.0  Cancelled 2016-07-15 17:55:33
# 2925        5476      Airport       27.0  Cancelled 2016-07-15 04:45:54
# 2944        5847      Airport       31.0  Cancelled 2016-07-15 09:05:38
# 2980        5945      Airport       39.0  Cancelled 2016-07-15 10:27:59
# 3089        6129      Airport       65.0  Cancelled 2016-07-15 15:36:17
# 3128        6098      Airport       73.0  Cancelled 2016-07-15 14:40:08
# 3157        5806      Airport       81.0  Cancelled 2016-07-15 08:46:33
# 3167        6209      Airport       83.0  Cancelled 2016-07-15 17:32:54
# 3212        6323      Airport       94.0  Cancelled 2016-07-15 18:39:39
# 3219        6390      Airport       96.0  Cancelled 2016-07-15 19:19:26
# 3254        5854      Airport      103.0  Cancelled 2016-07-15 09:09:32
# 3273        6300      Airport      107.0  Cancelled 2016-07-15 18:20:30
# ...

# %%
filtered_df.shape
# Out:
# (31, 8)

# %% [markdown]
# ###### How many trips in Airport & People cannot fined cars?

# %%
filtered_df = df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport') & (df['Status']== 'No Cars Available')]
filtered_df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 6165        6765      Airport        NaN  No Cars Available
# 6166        5388      Airport        NaN  No Cars Available
# 6168        5389      Airport        NaN  No Cars Available
# 6170        5390      Airport        NaN  No Cars Available
# 6172        5393      Airport        NaN  No Cars Available
# ...          ...          ...        ...                ...
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp Drop timestamp new_date_Request_timestamp  \
# 6165 2016-07-15 00:09:09            NaT                 2016-07-15
# 6166 2016-07-15 00:19:05            NaT                 2016-07-15
# ...

# %%
filtered_df.shape
# Out:
# (330, 8)

# %% [markdown]
# #### Who is the most Driver do his jop in this day?

# %% [markdown]
# #####  In City:

# %% [markdown]
# ###### Create new data frame:

# %% [markdown]
# We will create a new data frame to preserve the original data if we need it.

# %%
data2= df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City') & (df['Status']== 'Trip Completed')]
data2
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 8           6248         City        1.0  Trip Completed 2016-07-15 17:57:27
# 26          5434         City        3.0  Trip Completed 2016-07-15 02:41:38
# 27          5916         City        3.0  Trip Completed 2016-07-15 10:00:43
# 57          5741         City        6.0  Trip Completed 2016-07-15 07:52:51
# 65          5898         City        7.0  Trip Completed 2016-07-15 09:50:28
# ...          ...          ...        ...             ...                 ...
# 2768        5687         City      293.0  Trip Completed 2016-07-15 07:15:09
# 2780        6509         City      294.0  Trip Completed 2016-07-15 20:32:52
# 2786        6475         City      295.0  Trip Completed 2016-07-15 20:20:10
# 2818        6271         City      298.0  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City      299.0  Trip Completed 2016-07-15 18:31:31
#
# ...

# %% [markdown]
# ###### The Driver is:

# %%
# data3['Driver id'].value_counts().idxmax()
data2['Driver id'].mode()
# Out:
# 0    23
# Name: Driver id, dtype: int64

# %%
data2[data2['Driver id']== 23]
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 8           6248         City         23  Trip Completed 2016-07-15 17:57:27
# 26          5434         City         23  Trip Completed 2016-07-15 02:41:38
# 27          5916         City         23  Trip Completed 2016-07-15 10:00:43
# 57          5741         City         23  Trip Completed 2016-07-15 07:52:51
# 65          5898         City         23  Trip Completed 2016-07-15 09:50:28
# ...          ...          ...        ...             ...                 ...
# 2768        5687         City         23  Trip Completed 2016-07-15 07:15:09
# 2780        6509         City         23  Trip Completed 2016-07-15 20:32:52
# 2786        6475         City         23  Trip Completed 2016-07-15 20:20:10
# 2818        6271         City         23  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City         23  Trip Completed 2016-07-15 18:31:31
#
# ...

# %%
data2[data2['Driver id']== 23].shape
# Out:
# (293, 8)

# %% [markdown]
# #####  In Airport:

# %% [markdown]
# ###### Create new data frame:

# %% [markdown]
# We will create a new data frame to preserve the original data if we need it.

# %%
data3= df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport') & (df['Status']== 'Trip Completed')]
data3
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 7           5510      Airport        1.0  Trip Completed 2016-07-15 05:11:52
# 36          5771      Airport        4.0  Trip Completed 2016-07-15 08:30:06
# 37          6106      Airport        4.0  Trip Completed 2016-07-15 15:01:20
# 47          5857      Airport        5.0  Trip Completed 2016-07-15 09:08:50
# 48          6690      Airport        5.0  Trip Completed 2016-07-15 22:41:41
# ...          ...          ...        ...             ...                 ...
# 2769        6724      Airport      293.0  Trip Completed 2016-07-15 23:20:36
# 2779        5519      Airport      294.0  Trip Completed 2016-07-15 05:11:57
# 2796        5634      Airport      296.0  Trip Completed 2016-07-15 06:44:16
# 2807        6067      Airport      297.0  Trip Completed 2016-07-15 13:55:13
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %% [markdown]
# ###### The Driver is:

# %%
# data3['Driver id'].value_counts().idxmax()
data3['Driver id'].mode()
# Out:
# 0    112.0
# Name: Driver id, dtype: float64

# %%
data3[data3['Driver id']== 112]
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 1083        5558      Airport      112.0  Trip Completed 2016-07-15 05:32:12
# 1084        5827      Airport      112.0  Trip Completed 2016-07-15 08:52:58
# 1085        6063      Airport      112.0  Trip Completed 2016-07-15 13:48:53
# 1086        6691      Airport      112.0  Trip Completed 2016-07-15 22:47:31
#
#           Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# 1083 2016-07-15 06:05:55                 2016-07-15                   05:32:12
# 1084 2016-07-15 09:29:41                 2016-07-15                   08:52:58
# 1085 2016-07-15 14:19:12                 2016-07-15                   13:48:53
# 1086 2016-07-16 00:01:05                 2016-07-15                   22:47:31

# %%
data3[data3['Driver id']== 112].shape
# Out:
# (4, 8)

# %% [markdown]
# #### Who is the most Driver has Cancelled his jop in this day?

# %% [markdown]
# #####  In City:

# %% [markdown]
# ###### Create new data frame:

# %%
data4= df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'City') & (df['Status']== 'Cancelled')]
data4
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 2834        5927         City        1.0  Cancelled 2016-07-15 10:12:40
# 2851        5547         City        6.0  Cancelled 2016-07-15 05:30:31
# 2852        5699         City        6.0  Cancelled 2016-07-15 07:25:53
# 2853        5701         City        6.0  Cancelled 2016-07-15 07:34:00
# 2883        5784         City       16.0  Cancelled 2016-07-15 08:34:59
# ...          ...          ...        ...        ...                 ...
# 4067        5812         City      293.0  Cancelled 2016-07-15 08:44:40
# 4079        5514         City      296.0  Cancelled 2016-07-15 05:08:25
# 4080        5690         City      296.0  Cancelled 2016-07-15 07:20:54
# 4083        5515         City      297.0  Cancelled 2016-07-15 05:13:03
# 4084        5535         City      297.0  Cancelled 2016-07-15 05:19:48
#
#      Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# ...

# %% [markdown]
# ###### The Driver is:

# %%
# data4['Driver id'].value_counts().idxmax()
data4['Driver id'].mode()
# Out:
# 0       6.0
# 1      50.0
# 2      70.0
# 3      89.0
# 4     117.0
# 5     121.0
# 6     142.0
# 7     154.0
# 8     157.0
# 9     199.0
# 10    203.0
# 11    217.0
# 12    256.0
# Name: Driver id, dtype: float64

# %% [markdown]
# #####  In Airport:

# %% [markdown]
# ###### Create new data frame:

# %%
data5= df.loc[(df['new_date_Request_timestamp'] == '2016-07-15') & (df['Pickup point'] == 'Airport') & (df['Status']== 'Cancelled')]
data5
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 2915        6249      Airport       24.0  Cancelled 2016-07-15 17:55:33
# 2925        5476      Airport       27.0  Cancelled 2016-07-15 04:45:54
# 2944        5847      Airport       31.0  Cancelled 2016-07-15 09:05:38
# 2980        5945      Airport       39.0  Cancelled 2016-07-15 10:27:59
# 3089        6129      Airport       65.0  Cancelled 2016-07-15 15:36:17
# 3128        6098      Airport       73.0  Cancelled 2016-07-15 14:40:08
# 3157        5806      Airport       81.0  Cancelled 2016-07-15 08:46:33
# 3167        6209      Airport       83.0  Cancelled 2016-07-15 17:32:54
# 3212        6323      Airport       94.0  Cancelled 2016-07-15 18:39:39
# 3219        6390      Airport       96.0  Cancelled 2016-07-15 19:19:26
# 3254        5854      Airport      103.0  Cancelled 2016-07-15 09:09:32
# 3273        6300      Airport      107.0  Cancelled 2016-07-15 18:20:30
# ...

# %% [markdown]
# ###### The Driver is:

# %%
# data5['Driver id'].value_counts().idxmax()
data5['Driver id'].mode()
# Out:
# 0    210.0
# Name: Driver id, dtype: float64

# %%
data5[data5['Driver id']== 210]
# Out:
#       Request id Pickup point  Driver id     Status   Request timestamp  \
# 3717        6131      Airport      210.0  Cancelled 2016-07-15 15:38:23
# 3718        6302      Airport      210.0  Cancelled 2016-07-15 18:29:19
# 3719        6538      Airport      210.0  Cancelled 2016-07-15 20:54:55
#
#      Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# 3717            NaT                 2016-07-15                   15:38:23
# 3718            NaT                 2016-07-15                   18:29:19
# 3719            NaT                 2016-07-15                   20:54:55

# %%
data5[data5['Driver id']== 210].shape
# Out:
# (3, 8)

# %% [markdown]
# ### What is the most complete Trips day?

# %% [markdown]
# #### Create new data frame:

# %% [markdown]
# We will create a new data frame to preserve the original data if we need it.

# %%
data6=df.copy()
data6
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp      Drop timestamp new_date_Request_timestamp  \
# 0    2016-11-07 11:51:00 2016-11-07 13:00:00                 2016-11-07
# 1    2016-11-07 17:57:00 2016-11-07 18:47:00                 2016-11-07
# ...

# %% [markdown]
# #### Drop NAN Values:

# %% [markdown]
# We will Drop all NAN values in rows and this includes (Cancelled & No Car Available).

# %%
# data6.dropna().reset_index(drop=True ,inplace=True)
data6.dropna()
data6.dropna(axis=0 ,inplace=True)
data6
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 0            619      Airport        1.0  Trip Completed 2016-11-07 11:51:00
# 1            867      Airport        1.0  Trip Completed 2016-11-07 17:57:00
# 2           1807         City        1.0  Trip Completed 2016-12-07 09:17:00
# 3           2532      Airport        1.0  Trip Completed 2016-12-07 21:08:00
# 4           3112         City        1.0  Trip Completed 2016-07-13 08:33:16
# ...          ...          ...        ...             ...                 ...
# 2826        1315      Airport      300.0  Trip Completed 2016-11-07 22:54:00
# 2827        2924         City      300.0  Trip Completed 2016-07-13 06:31:22
# 2828        3324      Airport      300.0  Trip Completed 2016-07-13 12:33:21
# 2829        3935      Airport      300.0  Trip Completed 2016-07-13 22:26:08
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %% [markdown]
# #### The Day is:

# %%
data6['new_date_Request_timestamp'].value_counts().idxmax()
# data6['new_date_Request_timestamp'].mode()
# Out:
# Timestamp('2016-11-07 00:00:00')

# %%
filtered_data6 = data6.loc[(data6['new_date_Request_timestamp'] == '2016-11-07')]
filtered_data6
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 0            619      Airport        1.0  Trip Completed 2016-11-07 11:51:00
# 1            867      Airport        1.0  Trip Completed 2016-11-07 17:57:00
# 9            267         City        2.0  Trip Completed 2016-11-07 06:46:00
# 18           535      Airport        3.0  Trip Completed 2016-11-07 10:00:00
# 19           960      Airport        3.0  Trip Completed 2016-11-07 18:45:00
# ...          ...          ...        ...             ...                 ...
# 2797          30      Airport      297.0  Trip Completed 2016-11-07 02:04:00
# 2798         195         City      297.0  Trip Completed 2016-11-07 06:05:00
# 2799         993         City      297.0  Trip Completed 2016-11-07 19:00:00
# 2819        1244         City      299.0  Trip Completed 2016-11-07 21:38:00
# 2826        1315      Airport      300.0  Trip Completed 2016-11-07 22:54:00
#
# ...

# %%
filtered_data6.shape
# Out:
# (601, 8)

# %% [markdown]
# ##### How many Trips are Completed in the City in this Day?

# %%
filtered_data6 = data6.loc[(data6['new_date_Request_timestamp'] == '2016-07-15') & (data6['Pickup point']== 'City')]
filtered_data6
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 8           6248         City        1.0  Trip Completed 2016-07-15 17:57:27
# 26          5434         City        3.0  Trip Completed 2016-07-15 02:41:38
# 27          5916         City        3.0  Trip Completed 2016-07-15 10:00:43
# 57          5741         City        6.0  Trip Completed 2016-07-15 07:52:51
# 65          5898         City        7.0  Trip Completed 2016-07-15 09:50:28
# ...          ...          ...        ...             ...                 ...
# 2768        5687         City      293.0  Trip Completed 2016-07-15 07:15:09
# 2780        6509         City      294.0  Trip Completed 2016-07-15 20:32:52
# 2786        6475         City      295.0  Trip Completed 2016-07-15 20:20:10
# 2818        6271         City      298.0  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City      299.0  Trip Completed 2016-07-15 18:31:31
#
# ...

# %%
filtered_data6.shape
# Out:
# (293, 8)

# %% [markdown]
# ##### How many Trips are Completed in the Airport in this Day?

# %%
filtered_data6 = data6.loc[(data6['new_date_Request_timestamp'] == '2016-07-15') & (data6['Pickup point']== 'Airport')]
filtered_data6
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 7           5510      Airport        1.0  Trip Completed 2016-07-15 05:11:52
# 36          5771      Airport        4.0  Trip Completed 2016-07-15 08:30:06
# 37          6106      Airport        4.0  Trip Completed 2016-07-15 15:01:20
# 47          5857      Airport        5.0  Trip Completed 2016-07-15 09:08:50
# 48          6690      Airport        5.0  Trip Completed 2016-07-15 22:41:41
# ...          ...          ...        ...             ...                 ...
# 2769        6724      Airport      293.0  Trip Completed 2016-07-15 23:20:36
# 2779        5519      Airport      294.0  Trip Completed 2016-07-15 05:11:57
# 2796        5634      Airport      296.0  Trip Completed 2016-07-15 06:44:16
# 2807        6067      Airport      297.0  Trip Completed 2016-07-15 13:55:13
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %%
filtered_data6.shape
# Out:
# (268, 8)

# %% [markdown]
# ##### Who is the most successful driver?

# %% [markdown]
# ###### In City:

# %%
data7= data6.loc[(data6['new_date_Request_timestamp'] == '2016-07-15') & (data6['Pickup point']== 'City')]
data7
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 8           6248         City        1.0  Trip Completed 2016-07-15 17:57:27
# 26          5434         City        3.0  Trip Completed 2016-07-15 02:41:38
# 27          5916         City        3.0  Trip Completed 2016-07-15 10:00:43
# 57          5741         City        6.0  Trip Completed 2016-07-15 07:52:51
# 65          5898         City        7.0  Trip Completed 2016-07-15 09:50:28
# ...          ...          ...        ...             ...                 ...
# 2768        5687         City      293.0  Trip Completed 2016-07-15 07:15:09
# 2780        6509         City      294.0  Trip Completed 2016-07-15 20:32:52
# 2786        6475         City      295.0  Trip Completed 2016-07-15 20:20:10
# 2818        6271         City      298.0  Trip Completed 2016-07-15 18:14:56
# 2825        6304         City      299.0  Trip Completed 2016-07-15 18:31:31
#
# ...

# %%
data7['Driver id'].mode()
# Out:
# 0     23.0
# 1    289.0
# Name: Driver id, dtype: float64

# %% [markdown]
# ######  In Airport:

# %%
data8= data6.loc[(data6['new_date_Request_timestamp'] == '2016-07-15') & (data6['Pickup point']== 'Airport')]
data8
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 7           5510      Airport        1.0  Trip Completed 2016-07-15 05:11:52
# 36          5771      Airport        4.0  Trip Completed 2016-07-15 08:30:06
# 37          6106      Airport        4.0  Trip Completed 2016-07-15 15:01:20
# 47          5857      Airport        5.0  Trip Completed 2016-07-15 09:08:50
# 48          6690      Airport        5.0  Trip Completed 2016-07-15 22:41:41
# ...          ...          ...        ...             ...                 ...
# 2769        6724      Airport      293.0  Trip Completed 2016-07-15 23:20:36
# 2779        5519      Airport      294.0  Trip Completed 2016-07-15 05:11:57
# 2796        5634      Airport      296.0  Trip Completed 2016-07-15 06:44:16
# 2807        6067      Airport      297.0  Trip Completed 2016-07-15 13:55:13
# 2830        5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
# ...

# %%
data8['Driver id'].mode()
# Out:
# 0    112.0
# Name: Driver id, dtype: float64

# %%
data8[data8['Driver id']== 112]
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 1083        5558      Airport      112.0  Trip Completed 2016-07-15 05:32:12
# 1084        5827      Airport      112.0  Trip Completed 2016-07-15 08:52:58
# 1085        6063      Airport      112.0  Trip Completed 2016-07-15 13:48:53
# 1086        6691      Airport      112.0  Trip Completed 2016-07-15 22:47:31
#
#           Drop timestamp new_date_Request_timestamp new_time_Request_timestamp
# 1083 2016-07-15 06:05:55                 2016-07-15                   05:32:12
# 1084 2016-07-15 09:29:41                 2016-07-15                   08:52:58
# 1085 2016-07-15 14:19:12                 2016-07-15                   13:48:53
# 1086 2016-07-16 00:01:05                 2016-07-15                   22:47:31

# %%
data8[data8['Driver id']== 112].shape
# Out:
# (4, 8)
